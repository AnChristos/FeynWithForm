# %%
from FormUtils import pyForm

# %%
# %%pyForm QEDdiagrams
#
# * Example generating LO QED topologies
# #-
# * Above suppresses extra output
# Off Statistics;
# Off FinalStats;
#
# Vector p1,...,p10, q1,...,q10;
# Set ext : p1,...,p10;
# Set int : q1,...,q10;
#
# Model QED;
#   Particle eMinus,ePlus, -1;
#   Particle muMinus, muPlus    -1;
#   Particle ph,                0;
#   Vertex ePlus, eMinus, ph: alpha;
#   Vertex muMinus, muPlus, ph: alpha;
# EndModel;
#
# Local Annih = diagrams_(QED, {ePlus, eMinus}, {muPlus, muMinus}, ext, int, 0);
#
# Local Bhabha = diagrams_(QED, {ePlus, eMinus}, {ePlus, eMinus}, ext, int, 0);
#
# Local Moller = diagrams_(QED, {eMinus, eMinus}, {eMinus, eMinus}, ext, int, 0);
#
# Local ggee = diagrams_(QED, {ph, ph}, {ePlus, eMinus}, ext, int, 0);
#
# Local eegg = diagrams_(QED, {ePlus, eMinus}, {ph, ph}, ext, int, 0);
#
# Local compton = diagrams_(QED, {ph, eMinus}, {ph, eMinus}, ext, int, 0);
# .sort
# Print +ss;
# .end
# Out:
# FORM 5.0.0 (Jan 27 2026, v5.0.0)                 Run: Tue Apr 14 22:37:34 2026
#
#     * Example generating LO QED topologies
#     #-
#
#    Annih =
#        +
#          topo_(1)
#          *node_(1,1,eMinus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,muPlus(-p3))
#          *node_(4,1,muMinus(-p4))
#          *node_(5,alpha,ePlus(p1),eMinus(p2),ph(-q1))
#          *node_(6,alpha,muMinus(p3),muPlus(p4),ph(q1))
#       ;
#
#    Bhabha =
#        +
#          topo_(1)
#          *node_(1,1,eMinus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,ePlus(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(p1),eMinus(p2),ph(-q1))
#          *node_(6,alpha,ePlus(p4),eMinus(p3),ph(q1))
#        -
#          topo_(2)
#          *node_(1,1,eMinus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,ePlus(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(p1),eMinus(p3),ph(-q1))
#          *node_(6,alpha,ePlus(p4),eMinus(p2),ph(q1))
#       ;
#
#    Moller =
#        +
#          topo_(2)
#          *node_(1,1,ePlus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,eMinus(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(p3),eMinus(p1),ph(-q1))
#          *node_(6,alpha,ePlus(p4),eMinus(p2),ph(q1))
#        -
#          topo_(3)
#          *node_(1,1,ePlus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,eMinus(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(p4),eMinus(p1),ph(-q1))
#          *node_(6,alpha,ePlus(p3),eMinus(p2),ph(q1))
#       ;
#
#    ggee =
#        +
#          topo_(2)
#          *node_(1,1,ph(-p1))
#          *node_(2,1,ph(-p2))
#          *node_(3,1,ePlus(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(-q1),eMinus(p3),ph(p1))
#          *node_(6,alpha,ePlus(p4),eMinus(q1),ph(p2))
#        +
#          topo_(3)
#          *node_(1,1,ph(-p1))
#          *node_(2,1,ph(-p2))
#          *node_(3,1,ePlus(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(p4),eMinus(-q1),ph(p1))
#          *node_(6,alpha,ePlus(q1),eMinus(p3),ph(p2))
#       ;
#
#    eegg =
#        +
#          topo_(2)
#          *node_(1,1,eMinus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,ph(-p3))
#          *node_(4,1,ph(-p4))
#          *node_(5,alpha,ePlus(p1),eMinus(-q1),ph(p3))
#          *node_(6,alpha,ePlus(q1),eMinus(p2),ph(p4))
#        +
#          topo_(3)
#          *node_(1,1,eMinus(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,ph(-p3))
#          *node_(4,1,ph(-p4))
#          *node_(5,alpha,ePlus(p1),eMinus(-q1),ph(p4))
#          *node_(6,alpha,ePlus(q1),eMinus(p2),ph(p3))
#       ;
#
#    compton =
#        +
#          topo_(1)
#          *node_(1,1,ph(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,ph(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(-q1),eMinus(p2),ph(p1))
#          *node_(6,alpha,ePlus(p4),eMinus(q1),ph(p3))
#        +
#          topo_(3)
#          *node_(1,1,ph(-p1))
#          *node_(2,1,ePlus(-p2))
#          *node_(3,1,ph(-p3))
#          *node_(4,1,eMinus(-p4))
#          *node_(5,alpha,ePlus(p4),eMinus(-q1),ph(p1))
#          *node_(6,alpha,ePlus(q1),eMinus(p2),ph(p3))
#       ;
