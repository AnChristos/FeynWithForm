# %%
from FormUtils import pyForm, capture_physics_expr

# %%
# %%pyForm PionDecay
#
# * Process: pion -> fermion neutrino
#
# #include amplitude.inc
#
# * Constants and Kinematics
# Symbols Gf, Vud, fpi, ml, mpi;
#
#
# Local M = - (Gf/sqrt_(2)) * Vud * fpi * (
#             VB(i1, p3, ml) * g(i1, i2, pPion) * (g(i2, i3) - g(i2, i3, k5)) * U(i3, p4, 0)
#           );
#
# #call squareamplitude(M, Msq)
# .sort
# Multiply -1;
# .sort
#
# * --- Kinematics ---
# id p3.p3 = ml^2;
# id p4.p4 = 0;
# id pPion.pPion = mpi^2;
# id p3.p4 = (mpi^2 - ml^2)/2;
# id pPion.p3 = (mpi^2 + ml^2)/2;
# id pPion.p4 = (mpi^2 - ml^2)/2;
# .sort
#
# * Differential Decay Rate
# Local dGamma = ( pRest / (32 * pi^2 * mpi^2) ) * Msq;
# .sort
#
# id pRest = (mpi^2 - ml^2)/(2*mpi);
# .sort
#
# id 1/sqrt_(2)/sqrt_(2) = 1/2;
# bracket Gf, Vud, fpi, pi, mpi;
# .sort
#
# * Save to file
# Format C;
# #write <pi_decay_rate.txt> "%e;", dGamma;
# .sort
#
# * Print
# Format;
# bracket Gf, Vud, fpi, pi, mpi;
# Print Msq;
# Print dGamma;
# .end
#
# .end
# Out:
# FORM 5.0.0 (Jan 27 2026, v5.0.0)                 Run: Wed Apr  8 22:33:13 2026
#
#     * Process: pion -> fermion neutrino
#
#     #include amplitude.inc
#     *-------------------------------------------------------------------------*
#     * amplitude.inc
#     * Original Author: Jos Vermaseren (NIKHEF)
#     * See also : J.A.M.Vermaseren "New features of FORM" math-ph/0010025
#     *
#     * Core Procedure: squareamplitude
#     * Description:
#     * FORM procedure for squaring Feynman amplitudes,
#     * performing spin sums, and evaluating Dirac traces.
#     *-------------------------------------------------------------------------*
#
#     AutoDeclare Index i,mu,k;
#     AutoDeclare Symbol m,x;
#     AutoDeclare Vector p,q;
#     Vector q,q1,q2,p1,...,p10;
#     CF  UB,U,VB,V,g,gstring,eps;
#     CF  fprop,phprop,gprop,prop;
#     Index k5=0, k6=0, k7=0;
#     *
#     *
#     #procedure squareamplitude(Amp,Mat)
#     .sort
#     *
#     *   We skip everything but Amp. In Amp we look for the highest i and mu indices
#     *
#     Skip;
#     NSkip `Amp';
#     #$imax = 0;
#     #do i = 1,40
#         if ( match(VB(i`i',?a)) || match(V(i`i',?a))
#              || match(UB(i`i',?a)) || match(U(i`i',?a))
#              || match(g(i`i',?a)) || match(g(i?,i`i',?a))
#              || match(fprop(i`i',?a)) || match(fprop(i?,i`i',?a)) );
#                 $imax = `i';
#         endif;
#     #enddo
#     #$mumax = 0;
#     #do mu = 1,20
#         if ( match(g(?a,mu`mu')) || match(phprop(mu`mu',?a)) || match(phprop(mu?,mu`
#     mu',?a)) );
#             $mumax = `mu';
#         endif;
#     #enddo
#     .sort:amplitude-1;
#     *
#     *   Just for a check we print the highest i and mu indices
#     *
#     #message highest i is i`$imax', highest mu is mu`$mumax';
#     *
#     *   Now construct the conjugate
#     *
#     Skip;
#     L   `Amp'C = `Amp';
#     id  i_ = -i_;
#     *
#     *   Make a new set of dummy indices above $imax and $jmax.
#     *
#     Multiply replace_(<i1,i{`$imax'+1}>,...,<i`$imax',i{2*`$imax'}>);
#     Multiply replace_(<mu1,mu{`$mumax'+1}>,...,<mu`$mumax',mu{2*`$mumax'}>);
#     *
#     *   Exchange rows and columns
#     *
#     id  g(i1?,i2?,mu?) = g(i2,i1,mu);
#     id  fprop(i1?,i2?,?a) = fprop(i2,i1,?a);
#     id  phprop(mu1?,mu2?,p?) = phprop(mu2,mu1,p);
#     *
#     *   and exchange U and UB, V and VBAR
#     *
#     Multiply replace_(UB,U,U,UB,VB,V,V,VB);
#     *
#     *   gamma5 gets a minus sign. Hence k6 <--> k7
#     *
#     Multiply replace_(k6,k7,k7,k6);
#     id  g(?a,k5) = -g(?a,k5);
#     .sort:amplitude-2;
#     *
#     *   Now multiply Amp and AmpC to get the matrix element squared.
#     *
#     Skip;
#     Drop,`Amp',`Amp'C;
#     L   `Mat' = `Amp'*`Amp'C;
#     *
#     *   Spin sums
#     *
#     id  U(i1?,p?,m?)*UB(i2?,p?,m?) =  g(i1,i2,p)+g(i1,i2)*m;
#     id  V(i1?,p?,m?)*VB(i2?,p?,m?) = -g(i1,i2,p)+g(i1,i2)*m;
#     id  eps(mu1?,p?)*eps(mu2?,p?) = -d_(mu1,mu2);
#     *
#     *   Propagators
#     *
#     id  fprop(i1?,i2?,p?,m?) = (g(i1,i2,p)+g(i1,i2)*m)*prop(p.p-m^2);
#     id  phprop(mu1?,mu2?,q?) = -d_(mu1,mu2)*prop(q.q);
#     *
#     *   String the gamma matrices together in traces.
#     *
#     repeat;
#     * Handle:
#     * 1. g(i1,i2,?a)*g(i2,i3,?b) -> g(i1,i3,?a,?b)
#     * 2. g(i1,i2)*g(i2,i3,?a)    -> g(i1,i3,?a)
#     * 3. g(i1,i2)*g(i2,i3)       -> g(i1,i3)
#         id g(i1?,i2?,?a) * g(i2?,i3?,?b) = g(i1,i3,?a,?b);
#
#     * Handle  Unit with both indices matching gamma
#         id g(i1?,i2?) * g(i1?,i2?,?a) = g(i1,i1,?a);
#         id g(i1?,i2?) * g(i2?,i1?,?a) = g(i1,i1,?a);
#
#     * Trace of identity matrix
#         id g(i1?,i1?) = 4;
#     endrepeat;
#
#     .sort:amplitude-3;
#     Skip;
#     NSkip `Mat';
#     *
#     *   Now put the traces one by one in terms of the built in gammas
#     *
#     #do i = 1,10
#         id,once,g(i1?,i1?,?a) = g_(`i',?a);
#         id  g_(`i',k7) = g7_(`i');
#         al  g_(`i',k6) = g6_(`i');
#         al  g_(`i',k5) = g5_(`i');
#     #enddo
#     .sort:amplitude-4;
#     *
#     *   Finally take the traces
#     *
#     #do i = 1,10
#     Trace4,`i';
#     #enddo
#     #endprocedure
#
#
#     * Constants and Kinematics
#     Symbols Gf, Vud, fpi, ml, mpi;
#
#
#     Local M = - (Gf/sqrt_(2)) * Vud * fpi * (
#                 VB(i1, p3, ml) * g(i1, i2, pPion) * (g(i2, i3) - g(i2, i3, k5)) * U(
#     i3, p4, 0)
#               );
#
#     #call squareamplitude(M, Msq)
#
# Time =       0.00 sec    Generated terms =          2
#                M         Terms in output =          2
#                          Bytes used      =        328
#
# Time =       0.00 sec    Generated terms =          2
#                M         Terms in output =          2
#              amplitude-1 Bytes used      =        328
# ~~~highest i is i3, highest mu is mu0
#
# Time =       0.00 sec    Generated terms =          2
#               MC         Terms in output =          2
#              amplitude-2 Bytes used      =        328
#
# Time =       0.00 sec    Generated terms =          8
#              Msq         Terms in output =          8
#              amplitude-3 Bytes used      =       1012
#
# Time =       0.00 sec    Generated terms =          8
#              Msq         Terms in output =          8
#              amplitude-4 Bytes used      =        716
#     .sort
#
# Time =       0.00 sec    Generated terms =          4
#              Msq         Terms in output =          2
#                          Bytes used      =        268
#     Multiply -1;
#     .sort
#
# Time =       0.00 sec    Generated terms =          2
#              Msq         Terms in output =          2
#                          Bytes used      =        268
#
#     * --- Kinematics ---
#     id p3.p3 = ml^2;
#     id p4.p4 = 0;
#     id pPion.pPion = mpi^2;
#     id p3.p4 = (mpi^2 - ml^2)/2;
#     id pPion.p3 = (mpi^2 + ml^2)/2;
#     id pPion.p4 = (mpi^2 - ml^2)/2;
#     .sort
#
# Time =       0.00 sec    Generated terms =          6
#              Msq         Terms in output =          2
#                          Bytes used      =        236
#
#     * Differential Decay Rate
#     Local dGamma = ( pRest / (32 * pi^2 * mpi^2) ) * Msq;
#     .sort
#
# Time =       0.00 sec    Generated terms =          2
#              Msq         Terms in output =          2
#                          Bytes used      =        236
#
# Time =       0.00 sec    Generated terms =          2
#           dGamma         Terms in output =          2
#                          Bytes used      =        300
#
#     id pRest = (mpi^2 - ml^2)/(2*mpi);
#     .sort
#
# Time =       0.00 sec    Generated terms =          2
#              Msq         Terms in output =          2
#                          Bytes used      =        236
#
# Time =       0.00 sec    Generated terms =          4
#           dGamma         Terms in output =          3
#                          Bytes used      =        296
#
#     id 1/sqrt_(2)/sqrt_(2) = 1/2;
#     bracket Gf, Vud, fpi, pi, mpi;
#     .sort
#
# Time =       0.00 sec    Generated terms =          2
#              Msq         Terms in output =          2
#                          Bytes used      =        164
#
# Time =       0.00 sec    Generated terms =          3
#           dGamma         Terms in output =          3
#                          Bytes used      =        348
#
#     * Save to file
#     Format C;
#     #write <pi_decay_rate.txt> "%e;", dGamma;
#     .sort
#
# Time =       0.00 sec    Generated terms =          2
#              Msq         Terms in output =          2
#                          Bytes used      =        124
#
# Time =       0.00 sec    Generated terms =          3
#           dGamma         Terms in output =          3
#                          Bytes used      =        184
#
#     * Print
#     Format;
#     bracket Gf, Vud, fpi, pi, mpi;
#     Print Msq;
#     Print dGamma;
#     .end
#
# Time =       0.00 sec    Generated terms =          2
#              Msq         Terms in output =          2
#                          Bytes used      =        164
#
# Time =       0.00 sec    Generated terms =          3
#           dGamma         Terms in output =          3
#                          Bytes used      =        348
#
#    Msq =
#        + Gf^2*Vud^2*fpi^2 * (  - 2*ml^4 )
#
#        + Gf^2*Vud^2*fpi^2*mpi^2 * ( 2*ml^2 );
#
#    dGamma =
#        + Gf^2*Vud^2*fpi^2*mpi^(-3) * ( 1/32/(pi*pi)*ml^6 )
#
#        + Gf^2*Vud^2*fpi^2*mpi^(-1) * (  - 1/16/(pi*pi)*ml^4 )
#
#        + Gf^2*Vud^2*fpi^2*mpi * ( 1/32/(pi*pi)*ml^2 );
#
#   0.00 sec out of 0.00 sec
